# %% [markdown]
# <a href="https://colab.research.google.com/github/RaniaBZ/AIML_projects_and_labs/blob/main/AIML_Project_Module_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project for Module 4: Perceptron and Gradient Descent
#
# NOTE: YOU NEED TO WRITE CODE IN CELLS THAT SPECIFICALLY MENTION TASK-1, TASK-2, etc.
#
# WRITE ANY OBSERVATION(S), IF REQUIRED BY THE TASK, IN A SEPARATE CELL AT THE BOTTOM OF THE NOTEBOOK.
#
# ---

# %% [markdown]
# # Notebook Imports and Packages

# %%
import matplotlib.pyplot as plt
import numpy as np

from mpl_toolkits.mplot3d.axes3d import Axes3D
from matplotlib import cm # color map

from sympy import symbols, diff
from math import log

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %matplotlib inline

# %% [markdown]
# # Example 1 - A simple cost function
#
# ## $$f(x) = x^2 + x + 1$$

# %%
def f(x):
    return x ** 2 + x + 1

# %%
# Make Data
x_1 = np.linspace(start=-3, stop=3, num=500)

# %%
# Plot
plt.xlim(-3, 3)
plt.ylim(0, 8)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)
plt.plot(x_1, f(x_1))
plt.show()

# %% [markdown]
# ## Slope & Derivatives
#
# Creating a function for the derivative of $f(x)$ called df(x)

# %%
def df(x):
    return 2 * x + 1

# %%
# Plot function and derivative side by side
plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

plt.xlim(-3, 3)
plt.ylim(0, 8)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)

plt.plot(x_1, f(x_1), color='blue', linewidth=3)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('df(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 3)
plt.ylim(-3, 6)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=5)

plt.show()

# %% [markdown]
# ## Gradient Descent

# %%
##########################
##########################

## TASK-1 : Complete the lines of code wherever marked as [REQUIRED] in this cell.

##########################
##########################

# Gradient Descent
new_x = 3
previous_x = 0
step_multiplier = 0.1
precision = 0.00001

x_list = [new_x]
slope_list = [df(new_x)]

for n in range(500):
    previous_x = new_x
    gradient = df(previous_x)
    new_x = previous_x - step_multiplier * gradient

    step_size = abs(new_x - previous_x)
    # print(step_size)

    x_list.append(new_x)
    slope_list.append(df(new_x))

    if step_size < precision:
        print('Loop ran this many times:', n)
        break

print('Local minimum occurs at:', new_x)
print('Slope or df(x) value at this point is:', df(new_x))
print('f(x) value or cost at this point is:', f(new_x))
# Out:
# Loop ran this many times: 50
# Local minimum occurs at: -0.49996003706460423
# Slope or df(x) value at this point is: 7.992587079153068e-05
# f(x) value or cost at this point is: 0.7500000015970362

# %%
# Superimpose the gradient descent calculations on plot

plt.figure(figsize=[20, 5])

# 1 Chart: Cost function
plt.subplot(1, 3, 1)

plt.xlim(-3, 3)
plt.ylim(0, 8)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)

plt.plot(x_1, f(x_1), color='blue', linewidth=3, alpha=0.8)

values = np.array(x_list)
plt.scatter(x_list, f(values), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 3, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('df(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 3)
plt.ylim(-3, 6)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(x_list, slope_list, color='red', s=100, alpha=0.5)

# 3 Chart: Derivative (Close Up)
plt.subplot(1, 3, 3)

plt.title('Gradient Descent (close up)', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.grid()
plt.xlim(-0.55, -0.2)
plt.ylim(-0.3, 0.8)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=6, alpha=0.8)
plt.scatter(x_list, slope_list, color='red', s=300, alpha=0.6)


plt.show()

# %% [markdown]
# # Example 2 - Multiple Minima vs Initial Guess & Advanced Functions
#
# ## $$g(x) = x^4 - 4x^2 + 5$$

# %%
##########################
##########################

## TASK-2 : Complete the lines of code wherever marked as [REQUIRED] in this cell.

##########################
##########################

# Make some data
x_2 = np.linspace(-2, 2, 1000)

def g(x):
    return  x ** 3 - 2 * x ** 2 + 2

def dg(x):
    return  3 * x ** 2 - 4 * x

    plt.figure(figsize=(10, 5))

plt.plot(x_2, g(x_2), label='g(x)')
plt.plot(x_2, dg(x_2), label="g'(x) (derivative)")

plt.title('Function g(x) and its Derivative')
plt.xlabel('X', fontsize=16)
plt.ylabel('Value', fontsize=16)
plt.legend()

plt.show()

# %%
## TASK-3 : Plot function and derivative side by side like has been done earlier

# Superimpose the gradient descent calculations on plot

plt.figure(figsize=[20, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

plt.xlim(-2, 2)
plt.ylim(0, 8)

plt.title('Function g(x)', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)

plt.plot(x_2, g(x_2), color='green', linewidth=3, alpha=0.8)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Derivative of g(x)', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel("g'(x)", fontsize=16)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-6, 6)

plt.plot(x_2, dg(x_2), color='orange', linewidth=5, alpha=0.6)

plt.show()

# %% [markdown]
# ## Gradient Descent

# %%
def gradient_descent(derivative_func, initial_guess, multiplier=0.02, precision=0.001,
                    max_iter=300):
    new_x = initial_guess
    x_list = [new_x]
    slope_list = [derivative_func(new_x)]

    for n in range(max_iter):
        previous_x = new_x
        gradient = derivative_func(previous_x)
        new_x = previous_x - multiplier * gradient

        step_size = abs(new_x - previous_x)
        x_list.append(new_x)
        slope_list.append(derivative_func(new_x))

        if step_size < precision:
            break
    return new_x, x_list, slope_list

# %%
local_min, list_x, deriv_list = gradient_descent(dg, 0.5, 0.02, 0.001)
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: 1.321810121608152
# Number of steps: 65

# %%
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= -0.5,
                                                 multiplier=0.01, precision=0.0001)
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-29-45377b15b2e0> in <cell line: 1>()
# ----> 1 local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= -0.5,
#       2                                                  multiplier=0.01, precision=0.0001)
#       3 print('Local min occurs at:', local_min)
#       4 print('Number of steps:', len(list_x))
#
# <ipython-input-26-69ed7bdfe45d> in gradient_descent(derivative_func, initial_guess, multiplier, precision, max_iter)
#      12         step_size = abs(new_x - previous_x)
#      13         x_list.append(new_x)
# ---> 14         slope_list.append(derivative_func(new_x))
#      15
#      16         if step_size < precision:
#
# <ipython-input-24-f18587615a97> in dg(x)
#      14
#      15 def dg(x):
# ---> 16     return  3 * x ** 2 - 4 * x
#      17
#      18     plt.figure(figsize=(10, 5))
#
# OverflowError: (34, 'Numerical result out of range')

# %%
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= -0.1)
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-30-54cd58def11b> in <cell line: 1>()
# ----> 1 local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= -0.1)
#       2 print('Local min occurs at:', local_min)
#       3 print('Number of steps:', len(list_x))
#
# <ipython-input-26-69ed7bdfe45d> in gradient_descent(derivative_func, initial_guess, multiplier, precision, max_iter)
#      12         step_size = abs(new_x - previous_x)
#      13         x_list.append(new_x)
# ---> 14         slope_list.append(derivative_func(new_x))
#      15
#      16         if step_size < precision:
#
# <ipython-input-24-f18587615a97> in dg(x)
#      14
#      15 def dg(x):
# ---> 16     return  3 * x ** 2 - 4 * x
#      17
#      18     plt.figure(figsize=(10, 5))
#
# OverflowError: (34, 'Numerical result out of range')

# %%
# Calling gradient descent function
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= 0)

# Plot function and derivative and scatter plot side by side

plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

plt.xlim(-2, 2)
plt.ylim(0.5, 5.5)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)

plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(list_x, g(np.array(list_x)), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-6, 8)

plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(list_x, deriv_list, color='red', s=100, alpha=0.5)

plt.show()

# %% [markdown]
# # Example 3 - Divergence and Overflow
#
# ## $$h(x) = x^5 - 2x^4 + 2$$

# %%
## TASK-4 : Code the same things as they were done for the first two examples

# Define the gradient descent function
def gradient_descent(derivative_func, initial_guess, multiplier=0.02, precision=0.001,
                    max_iter=300):
    new_x = initial_guess
    x_list = [new_x]
    slope_list = [derivative_func(new_x)]

    for n in range(max_iter):
        previous_x = new_x
        gradient = derivative_func(previous_x)
        new_x = previous_x - multiplier * gradient

        step_size = abs(new_x - previous_x)
        x_list.append(new_x)
        slope_list.append(derivative_func(new_x))

        if step_size < precision:
            break
    return new_x, x_list, slope_list

# Apply gradient descent to find local minima
local_min_1, list_x_1, deriv_list_1 = gradient_descent(dg, 0.5, 0.02, 0.001)
local_min_2, list_x_2, deriv_list_2 = gradient_descent(dg, -0.5, 0.01, 0.0001)
local_min_3, list_x_3, deriv_list_3 = gradient_descent(dg, -0.1)

# Print results
print('Local min 1 occurs at:', local_min_1)
print('Number of steps for local min 1:', len(list_x_1))
print('Local min 2 occurs at:', local_min_2)
print('Number of steps for local min 2:', len(list_x_2))
print('Local min 3 occurs at:', local_min_3)
print('Number of steps for local min 3:', len(list_x_3))

# Plot function and derivative and scatter plot side by side

plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

plt.xlim(-2, 2)
plt.ylim(0.5, 5.5)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)

plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(list_x_1, g(np.array(list_x_1)), color='red', s=100, alpha=0.6, label='Min 1')
plt.scatter(list_x_2, g(np.array(list_x_2)), color='green', s=100, alpha=0.6, label='Min 2')
plt.scatter(list_x_3, g(np.array(list_x_3)), color='orange', s=100, alpha=0.6, label='Min 3')
plt.legend()

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-6, 8)

plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(list_x_1, deriv_list_1, color='red', s=100, alpha=0.5, label='Min 1')
plt.scatter(list_x_2, deriv_list_2, color='green', s=100, alpha=0.5, label='Min 2')
plt.scatter(list_x_3, deriv_list_3, color='orange', s=100, alpha=0.5, label='Min 3')
plt.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-32-5ba2f4d9b398> in <cell line: 25>()
#      23 # Apply gradient descent to find local minima
#      24 local_min_1, list_x_1, deriv_list_1 = gradient_descent(dg, 0.5, 0.02, 0.001)
# ---> 25 local_min_2, list_x_2, deriv_list_2 = gradient_descent(dg, -0.5, 0.01, 0.0001)
#      26 local_min_3, list_x_3, deriv_list_3 = gradient_descent(dg, -0.1)
#      27
#
# <ipython-input-32-5ba2f4d9b398> in gradient_descent(derivative_func, initial_guess, multiplier, precision, max_iter)
#      15         step_size = abs(new_x - previous_x)
#      16         x_list.append(new_x)
# ---> 17         slope_list.append(derivative_func(new_x))
#      18
#      19         if step_size < precision:
#
# <ipython-input-24-f18587615a97> in dg(x)
#      14
#      15 def dg(x):
# ---> 16     return  3 * x ** 2 - 4 * x
#      17
#      18     plt.figure(figsize=(10, 5))
#
# OverflowError: (34, 'Numerical result out of range')

# %% [markdown]
# # The Learning Rate

# %%
# Calling gradient descent function
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= 1.9,
                                                multiplier=0.02, max_iter=500)

# Plot function and derivative and scatter plot side by side

plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

plt.xlim(-2, 2)
plt.ylim(0.5, 5.5)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)

plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(list_x, g(np.array(list_x)), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-6, 8)

plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(list_x, deriv_list, color='red', s=100, alpha=0.5)

plt.show()

print('Number of steps is: ', len(list_x))
# Out:
# Number of steps is:  44

# %%
## TASK-5 : Run gradient descent 3 times
initial_guess_low_gamma = 3
multiplier_low_gamma = 0.0005
precision_low_gamma = 0.0001
max_iter_low_gamma = 100
low_gamma = gradient_descent(derivative_func=dg, initial_guess=initial_guess_low_gamma,
                             multiplier=multiplier_low_gamma, precision=precision_low_gamma,
                             max_iter=max_iter_low_gamma)

## TASK-6 : Plot two more learning rates: mid_gamma (0.001) and high_gamma (0.002)
n = 100
low_gamma = gradient_descent(derivative_func=dg, initial_guess= 3,
                                                multiplier=0.0005, precision=0.0001, max_iter=n)

initial_guess_mid_gamma = 3
multiplier_mid_gamma = 0.001
precision_mid_gamma = 0.0001
max_iter_mid_gamma = 100
mid_gamma = gradient_descent(derivative_func=dg, initial_guess=initial_guess_mid_gamma,
                             multiplier=multiplier_mid_gamma, precision=precision_mid_gamma,
                             max_iter=max_iter_mid_gamma)

initial_guess_high_gamma = 3
multiplier_high_gamma = 0.002
precision_high_gamma = 0.0001
max_iter_high_gamma = 100
high_gamma = gradient_descent(derivative_func=dg, initial_guess=initial_guess_high_gamma,
                              multiplier=multiplier_high_gamma, precision=precision_high_gamma,
                              max_iter=max_iter_high_gamma)



mid_gamma = gradient_descent(derivative_func=dg, initial_guess=initial_guess_mid_gamma,
                             multiplier=multiplier_mid_gamma, precision=precision_mid_gamma,
                             max_iter=max_iter_mid_gamma)
high_gamma = gradient_descent(derivative_func=dg, initial_guess=initial_guess_high_gamma,
                              multiplier=multiplier_high_gamma, precision=precision_high_gamma,
                              max_iter=max_iter_high_gamma)

# Experiment
insane_gamma = gradient_descent(derivative_func=dg, initial_guess= 1.9,
                                                multiplier=0.25, precision=0.0001, max_iter=n)

# %%
## TASK-7 : Plot reduction in cost for each iteration

# Function to calculate cost for a given value of x
def cost_function(x):
    return g(x)

# Function to plot the reduction in cost for each iteration
def plot_cost_reduction(iter_values, cost_func, label):
    plt.figure(figsize=[10, 5])
    plt.title('Reduction in Cost over Iterations', fontsize=17)
    plt.xlabel('Iterations', fontsize=16)
    plt.ylabel('Cost', fontsize=16)
    plt.plot(iter_values, [cost_func(val) for val in iter_values], label=label)
    plt.legend()
    plt.show()

# Calling gradient descent function for learning rate 0.02
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess=1.9,
                                                  multiplier=0.02, max_iter=500)

# Plot the reduction in cost for learning rate 0.02
plot_cost_reduction(list_x, cost_function, label='Learning Rate: 0.02')

# %% [markdown]
# # Example 4 - Data Viz with 3D Charts
#
# ## Minimise $$f(x, y) = \frac{1}{3^{-x^2 - y^2} + 1}$$
#
# Minimise $$f(x, y) = \frac{1}{r + 1}$$ where $r$ is $3^{-x^2 - y^2}$

# %%
## TASK-8 : Code the same things as they were done for the first two examples
# Function to calculate cost for a given value of x
def cost_function(x):
    return g(x)

# Function to plot the reduction in cost for each iteration
def plot_cost_reduction(iter_values, cost_func, label):
    plt.figure(figsize=[10, 5])
    plt.title('Reduction in Cost over Iterations', fontsize=17)
    plt.xlabel('Iterations', fontsize=16)
    plt.ylabel('Cost', fontsize=16)
    plt.plot(iter_values, [cost_func(val) for val in iter_values], label=label)
    plt.legend()
    plt.show()

# Calling gradient descent function for learning rate 0.02
local_min_1, list_x_1, deriv_list_1 = gradient_descent(derivative_func=dg, initial_guess=1.9,
                                                      multiplier=0.02, max_iter=500)

# Plot the function, its derivative, and the reduction in cost for learning rate 0.02
plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 3, 1)

plt.xlim(-2, 2)
plt.ylim(0.5, 5.5)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)

plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(list_x_1, g(np.array(list_x_1)), color='red', s=100, alpha=0.6, label='0.02')
plt.legend()

# 2 Chart: Derivative
plt.subplot(1, 3, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-6, 8)

plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(list_x_1, deriv_list_1, color='red', s=100, alpha=0.5, label='0.02')
plt.legend()

# 3 Chart: Reduction in Cost
plt.subplot(1, 3, 3)

plt.title('Reduction in Cost over Iterations', fontsize=17)
plt.xlabel('Iterations', fontsize=16)
plt.ylabel('Cost', fontsize=16)
plt.plot(list_x_1, [cost_function(val) for val in list_x_1], label='Learning Rate: 0.02')
plt.legend()

plt.show()

# %%
# Make our x and y data
x_4 = np.linspace(start=-2, stop=2, num=200)
y_4 = np.linspace(start=-2, stop=2, num=200)

print('Shape of X array', x_4.shape)

x_4, y_4 = np.meshgrid(x_4, y_4)
print('Array after meshgrid: ', x_4.shape)
# Out:
# Shape of X array (200,)
# Array after meshgrid:  (200, 200)

# %%
# Generating 3D Plot
fig = plt.figure(figsize=(16, 12))
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('X', fontsize=20)
ax.set_ylabel('Y', fontsize=20)
ax.set_zlabel('f(x, y) - Cost', fontsize=20)

ax.plot_surface(x_4, y_4, f(x_4, y_4), cmap=cm.coolwarm, alpha=0.4)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-aa5c611162e8> in <cell line: 9>()
#       7 ax.set_zlabel('f(x, y) - Cost', fontsize=20)
#       8
# ----> 9 ax.plot_surface(x_4, y_4, f(x_4, y_4), cmap=cm.coolwarm, alpha=0.4)
#      10
#      11 plt.show()
#
# TypeError: f() takes 1 positional argument but 2 were given

# %% [markdown]
# ##########################
# ##########################
#
# ## TASK-9 : Complete the lines of text wherever marked as [REQUIRED] in this cell.
#
# ##########################
# ##########################
#
# ## Partial Derivatives & Symbolic Computation
#
# ## $$\frac{\partial f}{\partial x} = x, y = symbols('x y')
# partial_derivative_x = diff(x**2 + y**2 + x*y, x)
#
#
# ## $$\frac{\partial f}{\partial y} = partial_derivative_y = diff(x**2 + y**2 + x*y, y)

# %%
a, b = symbols('x, y')
print('Our cost function f(x, y) is: ', f(a, b))
print('Partial derivative wrt x is: ', diff(f(a, b), b))
print('Value of f(x,y) at x=1.8 y=1.0 is: ',
      f(a, b).evalf(subs={a:1.8, b:1.0})) # Python Dictionary
print('Value of partial derivative wrt x: ', diff(f(a, b), a).evalf(subs={a:1.8, b:1.0}))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-076a7a187497> in <cell line: 2>()
#       1 a, b = symbols('x, y')
# ----> 2 print('Our cost function f(x, y) is: ', f(a, b))
#       3 print('Partial derivative wrt x is: ', diff(f(a, b), b))
#       4 print('Value of f(x,y) at x=1.8 y=1.0 is: ',
#       5       f(a, b).evalf(subs={a:1.8, b:1.0})) # Python Dictionary
#
# TypeError: f() takes 1 positional argument but 2 were given

# %% [markdown]
# ## Batch Gradient Descent with SymPy

# %%
# Setup
multiplier = 0.1
max_iter = 500
params = np.array([1.8, 1.0]) # initial guess

for n in range(max_iter):
    gradient_x = diff(f(a, b), a).evalf(subs={a:params[0], b:params[1]})
    gradient_y = diff(f(a, b), b).evalf(subs={a:params[0], b:params[1]})
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients

# Results
print('Values in gradient array', gradients)
print('Minimum occurs at x value of: ', params[0])
print('Minimum occurs at y value of: ', params[1])
print('The cost is: ', f(params[0], params[1]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-e2c6c992fb9c> in <cell line: 6>()
#       5
#       6 for n in range(max_iter):
# ----> 7     gradient_x = diff(f(a, b), a).evalf(subs={a:params[0], b:params[1]})
#       8     gradient_y = diff(f(a, b), b).evalf(subs={a:params[0], b:params[1]})
#       9     gradients = np.array([gradient_x, gradient_y])
#
# TypeError: f() takes 1 positional argument but 2 were given

# %%
##########################
##########################

## TASK-10 : Complete the lines of code wherever marked as [REQUIRED] in this cell.

##########################
##########################

# Partial derivative functions example 4
def fpx(x, y):
    return diff(f(a, b), a).evalf(subs={a: x, b: y})

def fpy(x, y):
    return diff(f(a, b), b).evalf(subs={a: x, b: y})

# %%
# Setup
multiplier = 0.1
max_iter = 500
params = np.array([1.8, 1.0]) # initial guess

for n in range(max_iter):
    gradient_x = fpx(params[0], params[1])
    gradient_y = fpy(params[0], params[1])
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients

# Results
print('Values in gradient array', gradients)
print('Minimum occurs at x value of: ', params[0])
print('Minimum occurs at y value of: ', params[1])
print('The cost is: ', f(params[0], params[1]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-3b38ae86a335> in <cell line: 4>()
#       2 multiplier = 0.1
#       3 max_iter = 500
# ----> 4 params = np.array([1.8, 1.0]) # initial guess
#       5
#       6 for n in range(max_iter):
#
# NameError: name 'np' is not defined

# %% [markdown]
# ## Graphing 3D Gradient Descent

# %%
# Setup
multiplier = 0.1
max_iter = 200
params = np.array([1.8, 1.0]) # initial guess
values_array = params.reshape(1, 2)
print(values_array.shape)

for n in range(max_iter):
    gradient_x = fpx(params[0], params[1])
    gradient_y = fpy(params[0], params[1])
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients
    #values_array = np.append(values_array, params.reshape(1, 2), axis=0)
    values_array = np.concatenate((values_array, params.reshape(1, 2)), axis=0)


# Results
print('Values in gradient array', gradients)
print('Minimum occurs at x value of: ', params[0])
print('Minimum occurs at y value of: ', params[1])
print('The cost is: ', f(params[0], params[1]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-409dd322aacb> in <cell line: 4>()
#       2 multiplier = 0.1
#       3 max_iter = 200
# ----> 4 params = np.array([1.8, 1.0]) # initial guess
#       5 values_array = params.reshape(1, 2)
#       6 print(values_array.shape)
#
# NameError: name 'np' is not defined

# %%
# Generating 3D Plot
fig = plt.figure(figsize=[16, 12])
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('X', fontsize=20)
ax.set_ylabel('Y', fontsize=20)
ax.set_zlabel('f(x, y) - Cost', fontsize=20)

ax.plot_surface(x_4, y_4, f(x_4, y_4), cmap=cm.coolwarm, alpha=0.4)
ax.scatter(values_array[:, 0], values_array[:, 1],
           f(values_array[:, 0], values_array[:, 1]), s=50, color='red')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-ad305cb454dc> in <cell line: 2>()
#       1 # Generating 3D Plot
# ----> 2 fig = plt.figure(figsize=[16, 12])
#       3 ax = fig.add_subplot(111, projection='3d')
#       4
#       5 ax.set_xlabel('X', fontsize=20)
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ## For Reference, practice and play with the code below
#
# # Example 5 - Working with Data & a Real Cost Function
#
# ## Mean Squared Error: a cost function for regression problems
#
# ### $$RSS = \sum_{i=1}^{n} \big( y^{(i)} - h_\theta x^{(i)} \big)^2 $$
# ### $$MSE = \frac{1}{n} \sum_{i=1}^{n} \big( y^{(i)} - h_\theta x^{(i)} \big)^2 $$
# ### $$MSE = \frac{1}{n} \sum_{i=1}^{n} \big( y - \hat{y} \big)^2 $$

# %%
# Make sample data
x_5 = np.array([[0.1, 1.2, 2.4, 3.2, 4.1, 5.7, 6.5]]).transpose()
y_5 = np.array([1.7, 2.4, 3.5, 3.0, 6.1, 9.4, 8.2]).reshape(7, 1)

print('Shape of x_5 array:', x_5.shape)
print('Shape of y_5 array:', y_5.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-802b8b9e12bb> in <cell line: 2>()
#       1 # Make sample data
# ----> 2 x_5 = np.array([[0.1, 1.2, 2.4, 3.2, 4.1, 5.7, 6.5]]).transpose()
#       3 y_5 = np.array([1.7, 2.4, 3.5, 3.0, 6.1, 9.4, 8.2]).reshape(7, 1)
#       4
#       5 print('Shape of x_5 array:', x_5.shape)
#
# NameError: name 'np' is not defined

# %%
# Quick linear regressino
regr = LinearRegression()
regr.fit(x_5, y_5)
print('Theta 0:', regr.intercept_[0])
print('Theta 1:', regr.coef_[0][0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-174b208cc3a2> in <cell line: 2>()
#       1 # Quick linear regressino
# ----> 2 regr = LinearRegression()
#       3 regr.fit(x_5, y_5)
#       4 print('Theta 0:', regr.intercept_[0])
#       5 print('Theta 1:', regr.coef_[0][0])
#
# NameError: name 'LinearRegression' is not defined

# %%
plt.scatter(x_5, y_5, s=50)
plt.plot(x_5, regr.predict(x_5), color='orange', linewidth=3)
plt.xlabel('x values')
plt.ylabel('y values')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-8ed2dd520f87> in <cell line: 1>()
# ----> 1 plt.scatter(x_5, y_5, s=50)
#       2 plt.plot(x_5, regr.predict(x_5), color='orange', linewidth=3)
#       3 plt.xlabel('x values')
#       4 plt.ylabel('y values')
#       5 plt.show()
#
# NameError: name 'plt' is not defined

# %%
# y_hat = theta0 + theta1*x
y_hat = 0.847535148603 + 1.22272646378*x_5
print('Est values y_hat are: \n', y_hat)
print('In comparison, the actual y values are \n', y_5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-b2465b0660e4> in <cell line: 2>()
#       1 # y_hat = theta0 + theta1*x
# ----> 2 y_hat = 0.847535148603 + 1.22272646378*x_5
#       3 print('Est values y_hat are: \n', y_hat)
#       4 print('In comparison, the actual y values are \n', y_5)
#
# NameError: name 'x_5' is not defined

# %%
# Challenge: Write a python function mse(y, y_hat) returns the MSE? Call the mse(y, y_hat)

def mse(y, y_hat):
    mse_calc = np.mean((y - y_hat)**2)
    return mse_calc
# function and print out the MSE for the y_hat calculated above.
y_hat_regr = regr.predict(x_5)

mse_value = mse(y_5, y_hat_regr)
print('Mean Squared Error (MSE) for linear regression predictions:', mse_value)

def mse(y, y_hat):
    #mse_calc = 1/7 * sum((y - y_hat)**2)
    #mse_calc = (1/y.size) * sum((y - y_hat)**2)
    mse_calc = np.average((y - y_hat)**2, axis=0)
    return mse_calc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-aedc7802ec1a> in <cell line: 7>()
#       5     return mse_calc
#       6 # function and print out the MSE for the y_hat calculated above.
# ----> 7 y_hat_regr = regr.predict(x_5)
#       8
#       9 mse_value = mse(y_5, y_hat_regr)
#
# NameError: name 'regr' is not defined

# %%
print('Manually calculated MSE is:', mse(y_5, y_hat))
print('MSE regression using manual calc is', mean_squared_error(y_5, y_hat))
print('MSE regression is', mean_squared_error(y_5, regr.predict(x_5)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-e57d70940b2a> in <cell line: 1>()
# ----> 1 print('Manually calculated MSE is:', mse(y_5, y_hat))
#       2 print('MSE regression using manual calc is', mean_squared_error(y_5, y_hat))
#       3 print('MSE regression is', mean_squared_error(y_5, regr.predict(x_5)))
#
# NameError: name 'y_5' is not defined

# %% [markdown]
# ## 3D Plot for the MSE Cost Function
#
# ### Make data for thetas

# %%
nr_thetas = 200
th_0 = np.linspace(start=-1, stop=3, num=nr_thetas)
th_1 = np.linspace(start=-1, stop=3, num=nr_thetas)
plot_t0, plot_t1 = np.meshgrid(th_0, th_1)

# %% [markdown]
# ### Calc MSE using nested for loops

# %%
plot_cost = np.zeros((nr_thetas, nr_thetas))

for i in range(nr_thetas):
    for j in range(nr_thetas):
        #print(plot_t0[j][i])
        y_hat = plot_t0[i][j] + plot_t1[i][j]*x_5
        plot_cost[i][j] = mse(y_5, y_hat)

print('Shape of plot_t0', plot_t0.shape)
print('Shape of plot_t1', plot_t1.shape)
print('Shape of plot_cost', plot_cost.shape)
# Out:
# Shape of plot_t0 (200, 200)
# Shape of plot_t1 (200, 200)
# Shape of plot_cost (200, 200)

# %%
# Plotting MSE
fig = plt.figure(figsize=[16, 12])
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('Theta 0', fontsize=20)
ax.set_ylabel('Theta 1', fontsize=20)
ax.set_zlabel('Cost - MSE', fontsize=20)

ax.plot_surface(plot_t0, plot_t1, plot_cost, cmap=cm.hot)
plt.show()

# %%
print('Min value of plot_cost', plot_cost.min())
ij_min = np.unravel_index(plot_cost.argmin(), plot_cost.shape)
print('Min occurs at (i,j):', ij_min)
print('Min MSE for Theta 0 at plot_t0[111][91]', plot_t0[ij_min[0]][ij_min[1]])
print('Min MSE for Theta 1 at plot_t1[111][91]', plot_t1[ij_min[0]][ij_min[1]])
# Out:
# Min value of plot_cost 0.948382652675
# Min occurs at (i,j): (111, 91)
# Min MSE for Theta 0 at plot_t0[111][91] 0.829145728643
# Min MSE for Theta 1 at plot_t1[111][91] 1.23115577889

# %% [markdown]
# ## Partial Derivatives of MSE w.r.t. $\theta_0$ and $\theta_1$
#
# ## $$\frac{\partial MSE}{\partial \theta_0} = - \frac{2}{n} \sum_{i=1}^{n} \big( y^{(i)} - \theta_0 - \theta_1 x^{(i)} \big)$$
#
# ## $$\frac{\partial MSE}{\partial \theta_1} = - \frac{2}{n} \sum_{i=1}^{n} \big( y^{(i)} - \theta_0 - \theta_1 x^{(i)} \big) \big( x^{(i)} \big)$$

# %% [markdown]
# ## MSE & Gradient Descent

# %%
# x values, y values, array of theta parameters (theta0 at index 0 and theta1 at index 1)
def grad(x, y, thetas):
    n = y.size

    # Challenge: Create theta0_slope and theta1_slope to hold slope values from partial derivs
    theta0_slope = (-2/n) * sum(y - thetas[0] - thetas[1]*x)
    theta1_slope = (-2/n) * sum((y - thetas[0] - thetas[1]*x)*x)

    #return np.array([theta0_slope[0], theta1_slope[0]])
    #return np.append(arr=theta0_slope, values=theta1_slope)
    return np.concatenate((theta0_slope, theta1_slope), axis=0)

# %%
multiplier = 0.01
thetas = np.array([2.9, 2.9])

# Collect data points for scatter plot
plot_vals = thetas.reshape(1, 2)
mse_vals = mse(y_5, thetas[0] + thetas[1]*x_5)

for i in range(1000):
    thetas = thetas - multiplier * grad(x_5, y_5, thetas)

    # Append the new values to our numpy arrays
    plot_vals = np.concatenate((plot_vals, thetas.reshape(1, 2)), axis=0)
    mse_vals = np.append(arr=mse_vals, values=mse(y_5, thetas[0] + thetas[1]*x_5))

# Results
print('Min occurs at Theta 0:', thetas[0])
print('Min occurs at Theta 1:', thetas[1])
print('MSE is:', mse(y_5, thetas[0] + thetas[1]*x_5))
# Out:
# Min occurs at Theta 0: 0.853223046174
# Min occurs at Theta 1: 1.22149353326
# MSE is: [ 0.94797511]

# %%
# Plotting MSE
fig = plt.figure(figsize=[16, 12])
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('Theta 0', fontsize=20)
ax.set_ylabel('Theta 1', fontsize=20)
ax.set_zlabel('Cost - MSE', fontsize=20)

ax.scatter(plot_vals[:, 0], plot_vals[:, 1], mse_vals, s=80, color='black')
ax.plot_surface(plot_t0, plot_t1, plot_cost, cmap=cm.rainbow, alpha=0.4)
plt.show()
